# %% [markdown]
# # git commit --amend
#
# repository에 올라간 마지막 commit을 수정
#
# 원격 저장소에 push할 경우 수정 수 강제 push 필요
#
# ```shell
# git commit -m 'initial commit'
# git add forgotten_file         # 잊었던 파일을 뒤늦게 추가...
# git commit --amend
# ```
