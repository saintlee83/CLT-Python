# %%
ls
# Out:
# notebook.ipynb  README.md

# %%
# !git init
# Out:
# Initialized empty Git repository in /Users/saintlee83/Documents/code/git_clones/CLT-Python/Lectures/L06_Git/.git/

# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x@  4 saintlee83  staff   128 Dec  1 12:35 .
# drwxr-xr-x@ 11 saintlee83  staff   352 Dec  1 11:10 ..
# -rw-r--r--@  1 saintlee83  staff  2392 Dec  1 12:35 notebook.ipynb
# -rw-r--r--@  1 saintlee83  staff     6 Dec  1 11:19 README.md

# %%
# !rm -rf .git
